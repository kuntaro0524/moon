# %%
import pandas as pd 

conds_df = pd.read_csv("./DBfiles/ZOOPREP_200525_HAMADA_BL32XU.csv", header=4)
# print(conds_df)

zoo_dict=conds_df.to_dict(orient='records')

# print(zoo_dict, len(zoo_dict))

# for d in zoo_dict:
#     print(d['PuckID'],d['PinID'], d['Mode'])

# conds_df.to_json("test.json", orient='records', lines=True)

new_df_from_json = pd.read_json("test.json", orient='records', lines=True)
print(new_df_from_json)
# Out:
#     PuckID  PinID     Mode  Wavelength[Å]  Loop size[µm]  Resolution limit[Å]  \
# 0     1094      1  helical            1.0            200                   99
# 1     1094      2  helical            1.0            200                   99
# 2     1094      3  helical            1.3            200                   99
# 3     1094      4  helical            1.0            200                   99
# 4     1094      5  helical            1.0            200                   99
# 5     1094      6  helical            1.0            200                   99
# 6     1094      7  helical            1.0            200                   99
# 7     1094      8  helical            1.0            200                   99
# 8     1094      9  helical            1.0            200                   99
# 9     1094     10  helical            1.0            200                   99
# 10    1094     11  helical            1.0            200                   99
# ...
