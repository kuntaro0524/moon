# %%
import pandas as pd

df = pd.read_csv("./DBfiles/ZOOPREP_200723_Yokoyama01_BL32XU_zoo.csv")

# Grouping by 'wavelength'
selection=(df.groupby(['wavelength']))

# print(selection, len(selection))
# print(selection.groups), len(selection.groups)

# for s,p in df.groupby(['wavelength']):
#     print(s,p.head(5))
    
# Grouping by 'wavelength' and 'raster_vbeam' and 'raster_hbeam'
file_index=0
for s,p in df.groupby(['wavelength', 'total_osc','mode']):
    print(s,p.head(5))
    p.to_csv("test%05d.csv"%file_index)

    file_index+=1
# Out:
# (0.9793, 720.0, 'helical')                                             root_dir  p_index     mode  \
# 0  /isilon/users/target/target/AutoUsers/200715/y...        0  helical
# 1  /isilon/users/target/target/AutoUsers/200715/y...        1  helical
# 2  /isilon/users/target/target/AutoUsers/200715/y...        2  helical
# 3  /isilon/users/target/target/AutoUsers/200715/y...        3  helical
# 4  /isilon/users/target/target/AutoUsers/200715/y...        4  helical
#
#     puckid  pinid sample_name  wavelength  raster_vbeam  raster_hbeam  \
# 0  RYT0006      1     P-G2-Se      0.9793          15.0          10.0
# 1  RYT0006      2     P-G2-Se      0.9793          15.0          10.0
# 2  RYT0006      3     P-G2-Se      0.9793          15.0          10.0
# 3  RYT0006      4     P-G2-Se      0.9793          15.0          10.0
# 4  RYT0006      5     P-G2-Se      0.9793          15.0          10.0
#
#    att_raster  ...  meas_name  cry_min_size_um  cry_max_size_um  hel_full_osc  \
# ...
